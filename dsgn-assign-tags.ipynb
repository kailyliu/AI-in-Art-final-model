# %%
dataset_dict = {
    'race_id': {
        0: 'white', 
        1: 'black', 
        2: 'asian', 
        3: 'indian', 
        4: 'others'
    },
    'gender_id': {
        0: 'male',
        1: 'female'
    }
}

# %%
import cv2
import numpy as np

# %%
from keras.models import load_model

model = load_model("model_checkpoint.keras")
# THIS ONE DOESNT WORK / NEEDS TO BE TRAINED
# model = load_model("final-model.keras") 

model.summary()
# Out:
# /Users/kailyliu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Model: "face_net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 198, 198,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 198, 198,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 198, 198,  │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 198, 198,  │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 198, 198,  │         64 │ activation[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 198, 198,  │         64 │ activation_4[0][… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 198, 198,  │         64 │ activation_8[0][… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 66, 66,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 66, 66,    │          0 │ max_pooling2d_3[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 66, 66,    │          0 │ max_pooling2d_6[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout_8[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 66, 66,    │          0 │ conv2d_1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 66, 66,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 66, 66,    │          0 │ conv2d_7[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_5[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_9[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_7[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_5[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_9[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 33, 33,    │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 33, 33,    │          0 │ conv2d_5[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 33, 33,    │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_2[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_6[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_10[0]… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_5[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ max_pooling2d_8[… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 8192)      │          0 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 8192)      │          0 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 8192)      │          0 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │  1,048,704 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │  1,048,704 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │  1,048,704 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128)       │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128)       │          0 │ dense_2[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 128)       │          0 │ dense_4[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_7[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_11[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │        645 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 2)         │        258 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output          │ (None, 1)         │          0 │ dense_1[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ race_output         │ (None, 5)         │          0 │ dense_3[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 2)         │          0 │ dense_5[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,575,450 (36.53 MB)
#  Trainable params: 3,191,400 (12.17 MB)
#  Non-trainable params: 1,248 (4.88 KB)
#  Optimizer params: 6,382,802 (24.35 MB)

# %%
from PIL import Image

print("Cashier Stats")

img_path = "job_images/cashier.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Cashier Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# [array([[0.25250232]], dtype=float32), array([[3.5080048e-01, 3.1121464e-05, 6.4722931e-01, 2.5344267e-04,
#         1.6856192e-03]], dtype=float32), array([[1.9956619e-04, 9.9978673e-01]], dtype=float32)]
# Predicted Gender: female
# Predicted Race: asian

# %%
from PIL import Image

print("CEO Stats")

img_path = "job_images/ceo.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# CEO Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.25442585]], dtype=float32), array([[9.9974424e-01, 1.3011397e-04, 2.5828704e-05, 4.5370639e-06,
#         9.5260068e-05]], dtype=float32), array([[9.9910378e-01, 8.5834874e-04]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: white

# %%
from PIL import Image

print("Construction Worker Stats")

img_path = "job_images/construction.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Construction Worker Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.30547735]], dtype=float32), array([[0.9618115 , 0.00803938, 0.00211852, 0.01608352, 0.01194708]],
#       dtype=float32), array([[9.9944746e-01, 5.4820825e-04]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: white

# %%
from PIL import Image

print("Drug Dealer Stats")

img_path = "job_images/dealer.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Drug Dealer Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.30672482]], dtype=float32), array([[0.6143627 , 0.19683151, 0.00415425, 0.00151483, 0.18313669]],
#       dtype=float32), array([[9.995867e-01, 3.731928e-04]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: white

# %%
from PIL import Image

print("Doctor Stats")

img_path = "job_images/doctor.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Doctor Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.20575145]], dtype=float32), array([[3.7060756e-02, 3.3610930e-05, 5.0900042e-01, 4.4761142e-01,
#         6.2938030e-03]], dtype=float32), array([[0.8458318 , 0.15971448]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: asian

# %%
from PIL import Image

print("Fast Food Worker Stats")

img_path = "job_images/fast-food.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Fast Food Worker Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.374157]], dtype=float32), array([[9.9973005e-01, 1.8429040e-05, 2.3945526e-04, 4.7824483e-06,
#         7.3214278e-06]], dtype=float32), array([[0.00136237, 0.9986067 ]], dtype=float32)]
# Predicted Gender: female
# Predicted Race: white

# %%
from PIL import Image

print("Inmate Stats")

img_path = "job_images/inmate.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Inmate Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.3411294]], dtype=float32), array([[0.35789937, 0.01828072, 0.5011195 , 0.10793434, 0.01476599]],
#       dtype=float32), array([[9.9970573e-01, 3.0194136e-04]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: asian

# %%
from PIL import Image

print("Lawyer Stats")

img_path = "job_images/lawyer.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Lawyer Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# [array([[0.21723181]], dtype=float32), array([[5.6974422e-02, 4.8700431e-06, 2.2556496e-04, 9.2834878e-01,
#         1.4446383e-02]], dtype=float32), array([[0.9957363 , 0.00391406]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: indian

# %%
from PIL import Image

print("Politician Stats")

img_path = "job_images/politician.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Politician Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [array([[0.2768603]], dtype=float32), array([[9.9654490e-01, 3.2715327e-03, 1.6118442e-05, 4.4877459e-05,
#         1.2260668e-04]], dtype=float32), array([[9.9999958e-01, 3.9245296e-07]], dtype=float32)]
# Predicted Gender: male
# Predicted Race: white

# %%
from PIL import Image

print("Teacher Stats")

img_path = "job_images/teacher.png"

im = Image.open(img_path)
im = im.convert('RGB')
im = im.resize((198, 198))
im = np.array(im) / 255.0

input_data = np.expand_dims(im, axis=0)

predictions = model.predict(input_data)
print(predictions)

# Extract predictions
predicted_race_id = np.argmax(predictions[1])
predicted_gender_id = np.argmax(predictions[2])
            
# Map gender and race predictions to their corresponding labels
predicted_gender = dataset_dict['gender_id'].get(predicted_gender_id, 'Unknown')
predicted_race = dataset_dict['race_id'].get(predicted_race_id, 'Unknown')
            
# Output the results
print("Predicted Gender:", predicted_gender)
print("Predicted Race:", predicted_race)
# Out:
# Teacher Stats
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# [array([[0.21327154]], dtype=float32), array([[0.05923579, 0.00195845, 0.08559094, 0.6998868 , 0.15332802]],
#       dtype=float32), array([[1.0662096e-04, 9.9989194e-01]], dtype=float32)]
# Predicted Gender: female
# Predicted Race: indian
