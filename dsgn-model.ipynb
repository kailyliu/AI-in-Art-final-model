# %%
dataset_folder_name = 'UTKFace'

TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198

dataset_dict = {
    'race_id': {
        0: 'white', 
        1: 'black', 
        2: 'asian', 
        3: 'indian', 
        4: 'others'
    },
    'gender_id': {
        0: 'male',
        1: 'female'
    }
}

dataset_dict['gender_alias'] = dict((g, i) for i, g in dataset_dict['gender_id'].items())
dataset_dict['race_alias'] = dict((g, i) for i, g in dataset_dict['race_id'].items())

# %%
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install plotly
# !pip3 install -U kaleido
# !pip3 install --upgrade nbformat
# !pip3 install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (3.8.4)
# Requirement already satisfied: pillow>=8 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.21 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: pandas>=1.2 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from seaborn) (2.2.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.18.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (5.20.0)
# Requirement already satisfied: packaging in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from plotly) (24.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from plotly) (8.2.3)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaleido in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (0.2.1)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nbformat in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (5.10.4)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from nbformat) (5.14.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from nbformat) (4.21.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from nbformat) (2.19.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (23.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.18.0)
# Requirement already satisfied: referencing>=0.28.4 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (0.34.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from jsonschema>=2.6->nbformat) (2023.12.1)
# Requirement already satisfied: platformdirs>=2.5 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.0)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pydot in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from pydot) (3.1.2)
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np 
import pandas as pd
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def parse_dataset(dataset_path, ext='jpg'):
    """
    Used to extract information about our dataset. It does iterate over all images and return a DataFrame with
    the data (age, gender and sex) of all files.
    """
    def parse_info_from_file(path):
        """
        Parse information from a single file
        """
        try:
            filename = os.path.split(path)[1]
            filename = os.path.splitext(filename)[0]
            age, gender, race, _ = filename.split('_')

            return int(age), dataset_dict['gender_id'][int(gender)], dataset_dict['race_id'][int(race)]
        except Exception as ex:
            return None, None, None
        
    files = glob.glob(os.path.join(dataset_path, "*.%s" % ext))
    
    records = []
    for file in files:
        info = parse_info_from_file(file)
        records.append(info)
        
    df = pd.DataFrame(records)
    df['file'] = files
    df.columns = ['age', 'gender', 'race', 'file']
    df = df.dropna()
    
    return df

# %%
df = parse_dataset(dataset_folder_name)
df.head()
# Out:
#     age  gender   race                                           file
# 0   9.0  female  asian   UTKFace/9_1_2_20161219204347420.jpg.chip.jpg
# 1  36.0    male  black  UTKFace/36_0_1_20170117163203851.jpg.chip.jpg
# 2  86.0  female  white  UTKFace/86_1_0_20170120225751953.jpg.chip.jpg
# 3  26.0  female  white  UTKFace/26_1_0_20170116171048641.jpg.chip.jpg
# 4   1.0  female  asian   UTKFace/1_1_2_20161219154612988.jpg.chip.jpg

# %%
import plotly.graph_objects as go
from IPython.display import display, Image

def plot_distribution(pd_series):
    labels = pd_series.value_counts().index.tolist()
    counts = pd_series.value_counts().values.tolist()
    
    pie_plot = go.Pie(labels=labels, values=counts, hole=.3)
    fig = go.Figure(data=[pie_plot])
    fig.update_layout(title_text='Distribution for %s' % pd_series.name)
        
    img_bytes = fig.to_image(format="png")
    display(Image(img_bytes))

# %%
plot_distribution(df['race'])

# %%
plot_distribution(df['gender'])

# %%
import plotly.express as px
fig = px.histogram(df, x="age", nbins=20)
fig.update_layout(title_text='Age distribution')
fig.show()

# %%
bins = [0, 10, 20, 30, 40, 60, 80, np.inf]
names = ['<10', '10-20', '20-30', '30-40', '40-60', '60-80', '80+']

age_binned = pd.cut(df['age'], bins, labels=names)
plot_distribution(age_binned)

# %%
from keras.utils import to_categorical
from PIL import Image

class UtkFaceDataGenerator():
    """
    Data generator for the UTKFace dataset. This class should be used when training our Keras multi-output model.
    """
    def __init__(self, df):
        self.df = df
        
    def generate_split_indexes(self):
        p = np.random.permutation(len(self.df))
        train_up_to = int(len(self.df) * TRAIN_TEST_SPLIT)
        train_idx = p[:train_up_to]
        test_idx = p[train_up_to:]

        train_up_to = int(train_up_to * TRAIN_TEST_SPLIT)
        train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]
        
        # converts alias to id
        self.df['gender_id'] = self.df['gender'].map(lambda gender: dataset_dict['gender_alias'][gender])
        self.df['race_id'] = self.df['race'].map(lambda race: dataset_dict['race_alias'][race])

        self.max_age = self.df['age'].max()
        
        return train_idx, valid_idx, test_idx
    
    def preprocess_image(self, img_path):
        """
        Used to perform some minor preprocessing on the image before inputting into the network.
        """
        im = Image.open(img_path)
        im = im.resize((IM_WIDTH, IM_HEIGHT))
        im = np.array(im) / 255.0
        
        return im
        
    def generate_images(self, image_idx, is_training, batch_size=16):
        """
        Used to generate a batch with images when training/testing/validating our Keras model.
        """
        
        # lists to store our batched data
        batch_images = []
        batch_ages = []
        batch_races = []
        batch_genders = []
        
        while True:
            for idx in image_idx:
                person = self.df.iloc[idx]
                
                age = person['age']
                race = person['race_id']
                gender = person['gender_id']
                file = person['file']
                
                im = self.preprocess_image(file)
                
                age_normalized = age / self.max_age
                race_categorical = to_categorical(race, len(dataset_dict['race_id']))
                gender_categorical = to_categorical(gender, len(dataset_dict['gender_id']))
                
                batch_images.append(im)
                batch_ages.append(age_normalized)
                batch_races.append(race_categorical)
                batch_genders.append(gender_categorical)
                
                # yielding condition
                if len(batch_images) >= batch_size:
                    yield np.array(batch_images), (np.array(batch_ages), np.array(batch_races), np.array(batch_genders))
                    batch_images = []
                    batch_ages = []
                    batch_races = []
                    batch_genders = []
                    
            if not is_training:
                break 

                    
data_generator = UtkFaceDataGenerator(df)
train_idx, valid_idx, test_idx = data_generator.generate_split_indexes()
# Out:
# /Users/kailyliu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning:
#
# urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020

# %%
from keras.models import Model
from keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Dropout, Lambda, Dense, Flatten, Input
import tensorflow as tf

class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for 
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """
    def make_default_hidden_layers(self, inputs):
        """
        Used to generate a default set of hidden layers. The structure used in this network is defined as:
        
        Conv2D -> BatchNormalization -> Pooling -> Dropout
        """
        x = Conv2D(16, (3, 3), padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(3, 3))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        return x

    def build_race_branch(self, inputs, num_races):
        """
        Used to build the race branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.
        """
        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(num_races)(x)
        x = Activation("softmax", name="race_output")(x)

        return x

    def build_gender_branch(self, inputs, num_genders=2):
        """
        Used to build the gender branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.
        """
        x = Lambda(lambda c: tf.image.rgb_to_grayscale(c))(inputs)

        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(num_genders)(x)
        x = Activation("sigmoid", name="gender_output")(x)

        return x

    def build_age_branch(self, inputs):   
        """
        Used to build the age branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.

        """
        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(128)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(1)(x)
        x = Activation("linear", name="age_output")(x)

        return x

    def assemble_full_model(self, width, height, num_races):
        """
        Used to assemble our multi-output model CNN.
        """
        input_shape = (height, width, 3)

        inputs = Input(shape=input_shape)

        age_branch = self.build_age_branch(inputs)
        race_branch = self.build_race_branch(inputs, num_races)
        gender_branch = self.build_gender_branch(inputs)

        model = Model(inputs=inputs,
                     outputs = [age_branch, race_branch, gender_branch],
                     name="face_net")

        return model
    
model = UtkMultiOutputModel().assemble_full_model(IM_WIDTH, IM_HEIGHT, num_races=len(dataset_dict['race_alias']))

# %%
model.summary()
# Out:
# Model: "face_net"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 198, 198,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 198, 198,  │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 198, 198,  │          0 │ conv2d[0][0]      │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 198, 198,  │          0 │ conv2d_3[0][0]    │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 198, 198,  │          0 │ conv2d_6[0][0]    │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 198, 198,  │         64 │ activation[0][0]  │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 198, 198,  │         64 │ activation_4[0][… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 198, 198,  │         64 │ activation_8[0][… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 66, 66,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 66, 66,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 66, 66,    │          0 │ max_pooling2d_3[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 66, 66,    │          0 │ max_pooling2d_6[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout_4[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 66, 66,    │      4,640 │ dropout_8[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 66, 66,    │          0 │ conv2d_1[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 66, 66,    │          0 │ conv2d_4[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 66, 66,    │          0 │ conv2d_7[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_1[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_5[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 66, 66,    │        128 │ activation_9[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 33, 33,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 33, 33,    │          0 │ max_pooling2d_7[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_1[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_5[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 33, 33,    │      9,248 │ dropout_9[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 33, 33,    │          0 │ conv2d_2[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 33, 33,    │          0 │ conv2d_5[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 33, 33,    │          0 │ conv2d_8[0][0]    │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_2[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_6[0][… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 33, 33,    │        128 │ activation_10[0]… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_2[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_5[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, 16, 16,    │          0 │ max_pooling2d_8[… │
# │ (Dropout)           │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 8192)      │          0 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 8192)      │          0 │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 8192)      │          0 │ dropout_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │  1,048,704 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 128)       │  1,048,704 │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │  1,048,704 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128)       │          0 │ dense[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128)       │          0 │ dense_2[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 128)       │          0 │ dense_4[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_3[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_7[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ activation_11[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 5)         │        645 │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 2)         │        258 │ dropout_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ age_output          │ (None, 1)         │          0 │ dense_1[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ race_output         │ (None, 5)         │          0 │ dense_3[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gender_output       │ (None, 2)         │          0 │ dense_5[0][0]     │
# │ (Activation)        │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,192,648 (12.18 MB)
#  Trainable params: 3,191,400 (12.17 MB)
#  Non-trainable params: 1,248 (4.88 KB)

# %%
from keras.optimizers import Adam

init_lr = 1e-4
epochs = 100

opt = Adam(learning_rate=init_lr)

model.compile(optimizer=opt, 
              loss={
                  'age_output': 'mse', 
                  'race_output': 'categorical_crossentropy', 
                  'gender_output': 'binary_crossentropy'},
              loss_weights={
                  'age_output': 4., 
                  'race_output': 1.5, 
                  'gender_output': 0.1},
              metrics={
                  'age_output': 'mae', 
                  'race_output': 'accuracy',
                  'gender_output': 'accuracy'})

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 32
valid_batch_size = 32
train_gen = data_generator.generate_images(train_idx, is_training=True, batch_size=batch_size)
valid_gen = data_generator.generate_images(valid_idx, is_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./model_checkpoint.keras", monitor='val_loss')
]


history = model.fit(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=epochs,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 928s 3s/step - age_output_mae: 1.2985 - gender_output_accuracy: 0.7013 - loss: 14.3198 - race_output_accuracy: 0.3522 - val_age_output_mae: 0.9170 - val_gender_output_accuracy: 0.5230 - val_loss: 14.6419 - val_race_output_accuracy: 0.4161
# Epoch 2/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 715s 2s/step - age_output_mae: 0.9856 - gender_output_accuracy: 0.7966 - loss: 8.6280 - race_output_accuracy: 0.5387 - val_age_output_mae: 1.3142 - val_gender_output_accuracy: 0.7786 - val_loss: 27.9426 - val_race_output_accuracy: 0.4669
# Epoch 3/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 562s 2s/step - age_output_mae: 0.8477 - gender_output_accuracy: 0.8142 - loss: 6.8447 - race_output_accuracy: 0.5890 - val_age_output_mae: 0.6924 - val_gender_output_accuracy: 0.8163 - val_loss: 14.8260 - val_race_output_accuracy: 0.4877
# Epoch 4/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 532s 1s/step - age_output_mae: 0.7483 - gender_output_accuracy: 0.8304 - loss: 5.6106 - race_output_accuracy: 0.6327 - val_age_output_mae: 0.9017 - val_gender_output_accuracy: 0.8238 - val_loss: 18.5910 - val_race_output_accuracy: 0.5202
# Epoch 5/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 543s 1s/step - age_output_mae: 0.6605 - gender_output_accuracy: 0.8394 - loss: 4.6137 - race_output_accuracy: 0.6708 - val_age_output_mae: 0.5208 - val_gender_output_accuracy: 0.8304 - val_loss: 9.6798 - val_race_output_accuracy: 0.5526
# Epoch 6/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 536s 1s/step - age_output_mae: 0.6022 - gender_output_accuracy: 0.8415 - loss: 4.0399 - race_output_accuracy: 0.6823 - val_age_output_mae: 0.4584 - val_gender_output_accuracy: 0.8298 - val_loss: 7.5223 - val_race_output_accuracy: 0.5992
# Epoch 7/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 517s 1s/step - age_output_mae: 0.5220 - gender_output_accuracy: 0.8474 - loss: 3.3475 - race_output_accuracy: 0.7011 - val_age_output_mae: 0.4624 - val_gender_output_accuracy: 0.8438 - val_loss: 8.2614 - val_race_output_accuracy: 0.6190
# Epoch 8/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 537s 1s/step - age_output_mae: 0.4699 - gender_output_accuracy: 0.8608 - loss: 2.9303 - race_output_accuracy: 0.7076 - val_age_output_mae: 0.4925 - val_gender_output_accuracy: 0.8375 - val_loss: 9.1612 - val_race_output_accuracy: 0.6504
# Epoch 9/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 543s 1s/step - age_output_mae: 0.4272 - gender_output_accuracy: 0.8646 - loss: 2.6214 - race_output_accuracy: 0.7231 - val_age_output_mae: 0.5496 - val_gender_output_accuracy: 0.8611 - val_loss: 10.0002 - val_race_output_accuracy: 0.6554
# Epoch 10/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 557s 2s/step - age_output_mae: 0.3760 - gender_output_accuracy: 0.8633 - loss: 2.2220 - race_output_accuracy: 0.7364 - val_age_output_mae: 0.5368 - val_gender_output_accuracy: 0.8558 - val_loss: 10.7915 - val_race_output_accuracy: 0.6589
# Epoch 11/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 512s 1s/step - age_output_mae: 0.3354 - gender_output_accuracy: 0.8744 - loss: 2.0018 - race_output_accuracy: 0.7291 - val_age_output_mae: 0.4969 - val_gender_output_accuracy: 0.8633 - val_loss: 9.5084 - val_race_output_accuracy: 0.6913
# Epoch 12/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 528s 1s/step - age_output_mae: 0.2926 - gender_output_accuracy: 0.8747 - loss: 1.7525 - race_output_accuracy: 0.7489 - val_age_output_mae: 0.5446 - val_gender_output_accuracy: 0.8696 - val_loss: 11.3843 - val_race_output_accuracy: 0.6788
# Epoch 13/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 521s 1s/step - age_output_mae: 0.2630 - gender_output_accuracy: 0.8766 - loss: 1.5908 - race_output_accuracy: 0.7600 - val_age_output_mae: 0.5473 - val_gender_output_accuracy: 0.8615 - val_loss: 11.7006 - val_race_output_accuracy: 0.6669
# Epoch 14/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 546s 2s/step - age_output_mae: 0.2335 - gender_output_accuracy: 0.8850 - loss: 1.4403 - race_output_accuracy: 0.7635 - val_age_output_mae: 0.5568 - val_gender_output_accuracy: 0.8690 - val_loss: 11.6295 - val_race_output_accuracy: 0.7181
# Epoch 15/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - age_output_mae: 0.2051 - gender_output_accuracy: 0.8837 - loss: 1.3340 - race_output_accuracy: 0.7665 - val_age_output_mae: 0.4503 - val_gender_output_accuracy: 0.8704 - val_loss: 8.6836 - val_race_output_accuracy: 0.7067
# Epoch 16/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 544s 2s/step - age_output_mae: 0.1806 - gender_output_accuracy: 0.8827 - loss: 1.2377 - race_output_accuracy: 0.7712 - val_age_output_mae: 0.4306 - val_gender_output_accuracy: 0.8736 - val_loss: 8.0428 - val_race_output_accuracy: 0.7321
# Epoch 17/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 561s 2s/step - age_output_mae: 0.1621 - gender_output_accuracy: 0.8868 - loss: 1.1701 - race_output_accuracy: 0.7774 - val_age_output_mae: 0.4560 - val_gender_output_accuracy: 0.8804 - val_loss: 8.7805 - val_race_output_accuracy: 0.7448
# Epoch 18/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 580s 2s/step - age_output_mae: 0.1465 - gender_output_accuracy: 0.8863 - loss: 1.0911 - race_output_accuracy: 0.7857 - val_age_output_mae: 0.4764 - val_gender_output_accuracy: 0.8762 - val_loss: 9.0768 - val_race_output_accuracy: 0.7331
# Epoch 19/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 589s 2s/step - age_output_mae: 0.1323 - gender_output_accuracy: 0.8949 - loss: 1.0493 - race_output_accuracy: 0.7817 - val_age_output_mae: 0.4334 - val_gender_output_accuracy: 0.8815 - val_loss: 8.1730 - val_race_output_accuracy: 0.7409
# Epoch 20/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 555s 2s/step - age_output_mae: 0.1196 - gender_output_accuracy: 0.8931 - loss: 1.0182 - race_output_accuracy: 0.7925 - val_age_output_mae: 0.5261 - val_gender_output_accuracy: 0.8865 - val_loss: 10.8759 - val_race_output_accuracy: 0.7478
# Epoch 21/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 561s 2s/step - age_output_mae: 0.1101 - gender_output_accuracy: 0.9024 - loss: 0.9879 - race_output_accuracy: 0.7968 - val_age_output_mae: 0.2562 - val_gender_output_accuracy: 0.8758 - val_loss: 4.6390 - val_race_output_accuracy: 0.7095
# Epoch 22/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 569s 2s/step - age_output_mae: 0.1048 - gender_output_accuracy: 0.9067 - loss: 0.9595 - race_output_accuracy: 0.7981 - val_age_output_mae: 0.2927 - val_gender_output_accuracy: 0.8885 - val_loss: 5.6109 - val_race_output_accuracy: 0.7343
# Epoch 23/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 550s 2s/step - age_output_mae: 0.0995 - gender_output_accuracy: 0.9068 - loss: 0.9290 - race_output_accuracy: 0.8017 - val_age_output_mae: 0.1982 - val_gender_output_accuracy: 0.8817 - val_loss: 3.2519 - val_race_output_accuracy: 0.7524
# Epoch 24/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 528s 1s/step - age_output_mae: 0.0931 - gender_output_accuracy: 0.9113 - loss: 0.8973 - race_output_accuracy: 0.8065 - val_age_output_mae: 0.2102 - val_gender_output_accuracy: 0.8808 - val_loss: 3.2387 - val_race_output_accuracy: 0.7510
# Epoch 25/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 510s 1s/step - age_output_mae: 0.0929 - gender_output_accuracy: 0.9174 - loss: 0.8734 - race_output_accuracy: 0.8136 - val_age_output_mae: 0.1277 - val_gender_output_accuracy: 0.8881 - val_loss: 1.7488 - val_race_output_accuracy: 0.7591
# Epoch 26/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 534s 1s/step - age_output_mae: 0.0915 - gender_output_accuracy: 0.9185 - loss: 0.8563 - race_output_accuracy: 0.8220 - val_age_output_mae: 0.1354 - val_gender_output_accuracy: 0.8871 - val_loss: 1.9736 - val_race_output_accuracy: 0.7476
# Epoch 27/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 554s 2s/step - age_output_mae: 0.0884 - gender_output_accuracy: 0.9168 - loss: 0.8383 - race_output_accuracy: 0.8165 - val_age_output_mae: 0.1356 - val_gender_output_accuracy: 0.8885 - val_loss: 1.9146 - val_race_output_accuracy: 0.7524
# Epoch 28/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 557s 2s/step - age_output_mae: 0.0874 - gender_output_accuracy: 0.9216 - loss: 0.8316 - race_output_accuracy: 0.8187 - val_age_output_mae: 0.1285 - val_gender_output_accuracy: 0.8905 - val_loss: 1.7193 - val_race_output_accuracy: 0.7589
# Epoch 29/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 531s 1s/step - age_output_mae: 0.0856 - gender_output_accuracy: 0.9239 - loss: 0.7970 - race_output_accuracy: 0.8303 - val_age_output_mae: 0.1079 - val_gender_output_accuracy: 0.8917 - val_loss: 1.6873 - val_race_output_accuracy: 0.7401
# Epoch 30/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 548s 2s/step - age_output_mae: 0.0845 - gender_output_accuracy: 0.9302 - loss: 0.7880 - race_output_accuracy: 0.8279 - val_age_output_mae: 0.0851 - val_gender_output_accuracy: 0.8925 - val_loss: 1.2345 - val_race_output_accuracy: 0.7659
# Epoch 31/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 561s 2s/step - age_output_mae: 0.0823 - gender_output_accuracy: 0.9302 - loss: 0.7669 - race_output_accuracy: 0.8337 - val_age_output_mae: 0.0820 - val_gender_output_accuracy: 0.8875 - val_loss: 1.3021 - val_race_output_accuracy: 0.7502
# Epoch 32/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 561s 2s/step - age_output_mae: 0.0823 - gender_output_accuracy: 0.9326 - loss: 0.7360 - race_output_accuracy: 0.8430 - val_age_output_mae: 0.0844 - val_gender_output_accuracy: 0.8907 - val_loss: 1.2677 - val_race_output_accuracy: 0.7698
# Epoch 33/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 519s 1s/step - age_output_mae: 0.0796 - gender_output_accuracy: 0.9328 - loss: 0.7407 - race_output_accuracy: 0.8360 - val_age_output_mae: 0.0802 - val_gender_output_accuracy: 0.8933 - val_loss: 1.2978 - val_race_output_accuracy: 0.7569
# Epoch 34/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 546s 2s/step - age_output_mae: 0.0796 - gender_output_accuracy: 0.9390 - loss: 0.7163 - race_output_accuracy: 0.8444 - val_age_output_mae: 0.0810 - val_gender_output_accuracy: 0.8935 - val_loss: 1.2067 - val_race_output_accuracy: 0.7659
# Epoch 35/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 591s 2s/step - age_output_mae: 0.0788 - gender_output_accuracy: 0.9432 - loss: 0.7126 - race_output_accuracy: 0.8462 - val_age_output_mae: 0.0754 - val_gender_output_accuracy: 0.8946 - val_loss: 1.2608 - val_race_output_accuracy: 0.7554
# Epoch 36/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 603s 2s/step - age_output_mae: 0.0783 - gender_output_accuracy: 0.9426 - loss: 0.6892 - race_output_accuracy: 0.8506 - val_age_output_mae: 0.0752 - val_gender_output_accuracy: 0.8929 - val_loss: 1.2618 - val_race_output_accuracy: 0.7613
# Epoch 37/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 604s 2s/step - age_output_mae: 0.0773 - gender_output_accuracy: 0.9451 - loss: 0.6858 - race_output_accuracy: 0.8484 - val_age_output_mae: 0.0738 - val_gender_output_accuracy: 0.8972 - val_loss: 1.1995 - val_race_output_accuracy: 0.7748
# Epoch 38/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 596s 2s/step - age_output_mae: 0.0770 - gender_output_accuracy: 0.9494 - loss: 0.6773 - race_output_accuracy: 0.8555 - val_age_output_mae: 0.0820 - val_gender_output_accuracy: 0.8956 - val_loss: 1.1853 - val_race_output_accuracy: 0.7694
# Epoch 39/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 591s 2s/step - age_output_mae: 0.0753 - gender_output_accuracy: 0.9475 - loss: 0.6614 - race_output_accuracy: 0.8603 - val_age_output_mae: 0.0898 - val_gender_output_accuracy: 0.8917 - val_loss: 1.2901 - val_race_output_accuracy: 0.7609
# Epoch 40/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 606s 2s/step - age_output_mae: 0.0755 - gender_output_accuracy: 0.9518 - loss: 0.6364 - race_output_accuracy: 0.8618 - val_age_output_mae: 0.0729 - val_gender_output_accuracy: 0.8933 - val_loss: 1.2140 - val_race_output_accuracy: 0.7700
# Epoch 41/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 635s 2s/step - age_output_mae: 0.0747 - gender_output_accuracy: 0.9500 - loss: 0.6123 - race_output_accuracy: 0.8687 - val_age_output_mae: 0.0880 - val_gender_output_accuracy: 0.8980 - val_loss: 1.2188 - val_race_output_accuracy: 0.7718
# Epoch 42/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 627s 2s/step - age_output_mae: 0.0738 - gender_output_accuracy: 0.9498 - loss: 0.5944 - race_output_accuracy: 0.8667 - val_age_output_mae: 0.0705 - val_gender_output_accuracy: 0.8996 - val_loss: 1.1452 - val_race_output_accuracy: 0.7786
# Epoch 43/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 622s 2s/step - age_output_mae: 0.0730 - gender_output_accuracy: 0.9497 - loss: 0.6012 - race_output_accuracy: 0.8734 - val_age_output_mae: 0.0822 - val_gender_output_accuracy: 0.8923 - val_loss: 1.2032 - val_race_output_accuracy: 0.7685
# Epoch 44/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 632s 2s/step - age_output_mae: 0.0727 - gender_output_accuracy: 0.9552 - loss: 0.5855 - race_output_accuracy: 0.8710 - val_age_output_mae: 0.1529 - val_gender_output_accuracy: 0.8948 - val_loss: 1.3570 - val_race_output_accuracy: 0.7718
# Epoch 45/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 615s 2s/step - age_output_mae: 0.0721 - gender_output_accuracy: 0.9544 - loss: 0.5916 - race_output_accuracy: 0.8736 - val_age_output_mae: 0.1010 - val_gender_output_accuracy: 0.8954 - val_loss: 1.2421 - val_race_output_accuracy: 0.7740
# Epoch 46/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 666s 2s/step - age_output_mae: 0.0711 - gender_output_accuracy: 0.9569 - loss: 0.5602 - race_output_accuracy: 0.8794 - val_age_output_mae: 0.0886 - val_gender_output_accuracy: 0.8901 - val_loss: 1.3230 - val_race_output_accuracy: 0.7548
# Epoch 47/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 668s 2s/step - age_output_mae: 0.0701 - gender_output_accuracy: 0.9593 - loss: 0.5637 - race_output_accuracy: 0.8766 - val_age_output_mae: 0.0685 - val_gender_output_accuracy: 0.8988 - val_loss: 1.2587 - val_race_output_accuracy: 0.7665
# Epoch 48/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 643s 2s/step - age_output_mae: 0.0702 - gender_output_accuracy: 0.9579 - loss: 0.5395 - race_output_accuracy: 0.8838 - val_age_output_mae: 0.0678 - val_gender_output_accuracy: 0.8968 - val_loss: 1.2027 - val_race_output_accuracy: 0.7768
# Epoch 49/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 605s 2s/step - age_output_mae: 0.0694 - gender_output_accuracy: 0.9544 - loss: 0.5415 - race_output_accuracy: 0.8814 - val_age_output_mae: 0.0826 - val_gender_output_accuracy: 0.8996 - val_loss: 1.2989 - val_race_output_accuracy: 0.7675
# Epoch 50/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 595s 2s/step - age_output_mae: 0.0684 - gender_output_accuracy: 0.9594 - loss: 0.5367 - race_output_accuracy: 0.8840 - val_age_output_mae: 0.0660 - val_gender_output_accuracy: 0.9004 - val_loss: 1.2049 - val_race_output_accuracy: 0.7736
# Epoch 51/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 606s 2s/step - age_output_mae: 0.0671 - gender_output_accuracy: 0.9608 - loss: 0.5153 - race_output_accuracy: 0.8876 - val_age_output_mae: 0.1119 - val_gender_output_accuracy: 0.8974 - val_loss: 1.4757 - val_race_output_accuracy: 0.7778
# Epoch 52/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 618s 2s/step - age_output_mae: 0.0682 - gender_output_accuracy: 0.9597 - loss: 0.4924 - race_output_accuracy: 0.8973 - val_age_output_mae: 0.0696 - val_gender_output_accuracy: 0.8938 - val_loss: 1.2879 - val_race_output_accuracy: 0.7772
# Epoch 53/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 620s 2s/step - age_output_mae: 0.0667 - gender_output_accuracy: 0.9595 - loss: 0.4918 - race_output_accuracy: 0.8907 - val_age_output_mae: 0.0717 - val_gender_output_accuracy: 0.8958 - val_loss: 1.2634 - val_race_output_accuracy: 0.7740
# Epoch 54/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 633s 2s/step - age_output_mae: 0.0668 - gender_output_accuracy: 0.9611 - loss: 0.4828 - race_output_accuracy: 0.8987 - val_age_output_mae: 0.0731 - val_gender_output_accuracy: 0.8863 - val_loss: 1.2690 - val_race_output_accuracy: 0.7750
# Epoch 55/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 647s 2s/step - age_output_mae: 0.0658 - gender_output_accuracy: 0.9583 - loss: 0.4836 - race_output_accuracy: 0.8982 - val_age_output_mae: 0.0680 - val_gender_output_accuracy: 0.8948 - val_loss: 1.2152 - val_race_output_accuracy: 0.7847
# Epoch 56/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 633s 2s/step - age_output_mae: 0.0662 - gender_output_accuracy: 0.9670 - loss: 0.4734 - race_output_accuracy: 0.8974 - val_age_output_mae: 0.0695 - val_gender_output_accuracy: 0.8875 - val_loss: 1.2060 - val_race_output_accuracy: 0.7821
# Epoch 57/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 606s 2s/step - age_output_mae: 0.0649 - gender_output_accuracy: 0.9666 - loss: 0.4486 - race_output_accuracy: 0.9032 - val_age_output_mae: 0.0677 - val_gender_output_accuracy: 0.9000 - val_loss: 1.2709 - val_race_output_accuracy: 0.7778
# Epoch 58/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 630s 2s/step - age_output_mae: 0.0666 - gender_output_accuracy: 0.9688 - loss: 0.4571 - race_output_accuracy: 0.8987 - val_age_output_mae: 0.0828 - val_gender_output_accuracy: 0.8986 - val_loss: 1.3069 - val_race_output_accuracy: 0.7768
# Epoch 59/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 614s 2s/step - age_output_mae: 0.0648 - gender_output_accuracy: 0.9674 - loss: 0.4507 - race_output_accuracy: 0.9041 - val_age_output_mae: 0.0671 - val_gender_output_accuracy: 0.8909 - val_loss: 1.2600 - val_race_output_accuracy: 0.7784
# Epoch 60/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 626s 2s/step - age_output_mae: 0.0657 - gender_output_accuracy: 0.9668 - loss: 0.4300 - race_output_accuracy: 0.9032 - val_age_output_mae: 0.0684 - val_gender_output_accuracy: 0.8925 - val_loss: 1.2835 - val_race_output_accuracy: 0.7754
# Epoch 61/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 647s 2s/step - age_output_mae: 0.0639 - gender_output_accuracy: 0.9709 - loss: 0.4445 - race_output_accuracy: 0.9010 - val_age_output_mae: 0.0741 - val_gender_output_accuracy: 0.8921 - val_loss: 1.3339 - val_race_output_accuracy: 0.7746
# Epoch 62/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 640s 2s/step - age_output_mae: 0.0648 - gender_output_accuracy: 0.9671 - loss: 0.4202 - race_output_accuracy: 0.9084 - val_age_output_mae: 0.0720 - val_gender_output_accuracy: 0.8919 - val_loss: 1.2707 - val_race_output_accuracy: 0.7802
# Epoch 63/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 633s 2s/step - age_output_mae: 0.0639 - gender_output_accuracy: 0.9701 - loss: 0.4027 - race_output_accuracy: 0.9152 - val_age_output_mae: 0.0705 - val_gender_output_accuracy: 0.8962 - val_loss: 1.2884 - val_race_output_accuracy: 0.7786
# Epoch 64/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 617s 2s/step - age_output_mae: 0.0633 - gender_output_accuracy: 0.9730 - loss: 0.4085 - race_output_accuracy: 0.9095 - val_age_output_mae: 0.0679 - val_gender_output_accuracy: 0.8964 - val_loss: 1.2668 - val_race_output_accuracy: 0.7849
# Epoch 65/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 619s 2s/step - age_output_mae: 0.0629 - gender_output_accuracy: 0.9739 - loss: 0.4075 - race_output_accuracy: 0.9108 - val_age_output_mae: 0.0647 - val_gender_output_accuracy: 0.8921 - val_loss: 1.3448 - val_race_output_accuracy: 0.7831
# Epoch 66/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 614s 2s/step - age_output_mae: 0.0624 - gender_output_accuracy: 0.9720 - loss: 0.3801 - race_output_accuracy: 0.9163 - val_age_output_mae: 0.0692 - val_gender_output_accuracy: 0.8974 - val_loss: 1.3372 - val_race_output_accuracy: 0.7835
# Epoch 67/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 616s 2s/step - age_output_mae: 0.0626 - gender_output_accuracy: 0.9727 - loss: 0.3765 - race_output_accuracy: 0.9205 - val_age_output_mae: 0.0661 - val_gender_output_accuracy: 0.8974 - val_loss: 1.2397 - val_race_output_accuracy: 0.7855
# Epoch 68/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 615s 2s/step - age_output_mae: 0.0630 - gender_output_accuracy: 0.9729 - loss: 0.3804 - race_output_accuracy: 0.9207 - val_age_output_mae: 0.0676 - val_gender_output_accuracy: 0.8917 - val_loss: 1.2495 - val_race_output_accuracy: 0.7861
# Epoch 69/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 635s 2s/step - age_output_mae: 0.0618 - gender_output_accuracy: 0.9666 - loss: 0.3802 - race_output_accuracy: 0.9161 - val_age_output_mae: 0.0694 - val_gender_output_accuracy: 0.8966 - val_loss: 1.2876 - val_race_output_accuracy: 0.7800
# Epoch 70/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 634s 2s/step - age_output_mae: 0.0619 - gender_output_accuracy: 0.9689 - loss: 0.3580 - race_output_accuracy: 0.9250 - val_age_output_mae: 0.0647 - val_gender_output_accuracy: 0.8990 - val_loss: 1.2784 - val_race_output_accuracy: 0.7861
# Epoch 71/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 635s 2s/step - age_output_mae: 0.0610 - gender_output_accuracy: 0.9720 - loss: 0.3580 - race_output_accuracy: 0.9196 - val_age_output_mae: 0.0637 - val_gender_output_accuracy: 0.8935 - val_loss: 1.2066 - val_race_output_accuracy: 0.7929
# Epoch 72/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 634s 2s/step - age_output_mae: 0.0618 - gender_output_accuracy: 0.9753 - loss: 0.3600 - race_output_accuracy: 0.9186 - val_age_output_mae: 0.0650 - val_gender_output_accuracy: 0.8948 - val_loss: 1.2455 - val_race_output_accuracy: 0.7899
# Epoch 73/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 638s 2s/step - age_output_mae: 0.0606 - gender_output_accuracy: 0.9755 - loss: 0.3748 - race_output_accuracy: 0.9158 - val_age_output_mae: 0.0646 - val_gender_output_accuracy: 0.8980 - val_loss: 1.3661 - val_race_output_accuracy: 0.7736
# Epoch 74/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 628s 2s/step - age_output_mae: 0.0608 - gender_output_accuracy: 0.9747 - loss: 0.3541 - race_output_accuracy: 0.9205 - val_age_output_mae: 0.0672 - val_gender_output_accuracy: 0.8972 - val_loss: 1.2991 - val_race_output_accuracy: 0.7865
# Epoch 75/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 638s 2s/step - age_output_mae: 0.0611 - gender_output_accuracy: 0.9772 - loss: 0.3526 - race_output_accuracy: 0.9215 - val_age_output_mae: 0.0817 - val_gender_output_accuracy: 0.8966 - val_loss: 1.4455 - val_race_output_accuracy: 0.7782
# Epoch 76/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 623s 2s/step - age_output_mae: 0.0597 - gender_output_accuracy: 0.9700 - loss: 0.3502 - race_output_accuracy: 0.9225 - val_age_output_mae: 0.0754 - val_gender_output_accuracy: 0.8956 - val_loss: 1.3077 - val_race_output_accuracy: 0.7839
# Epoch 77/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 619s 2s/step - age_output_mae: 0.0607 - gender_output_accuracy: 0.9740 - loss: 0.3509 - race_output_accuracy: 0.9235 - val_age_output_mae: 0.1042 - val_gender_output_accuracy: 0.8952 - val_loss: 1.2957 - val_race_output_accuracy: 0.7891
# Epoch 78/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 623s 2s/step - age_output_mae: 0.0611 - gender_output_accuracy: 0.9739 - loss: 0.3395 - race_output_accuracy: 0.9293 - val_age_output_mae: 0.1276 - val_gender_output_accuracy: 0.8927 - val_loss: 1.3555 - val_race_output_accuracy: 0.7812
# Epoch 79/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 627s 2s/step - age_output_mae: 0.0599 - gender_output_accuracy: 0.9773 - loss: 0.3201 - race_output_accuracy: 0.9344 - val_age_output_mae: 0.0664 - val_gender_output_accuracy: 0.8972 - val_loss: 1.3467 - val_race_output_accuracy: 0.7841
# Epoch 80/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 599s 2s/step - age_output_mae: 0.0592 - gender_output_accuracy: 0.9754 - loss: 0.3322 - race_output_accuracy: 0.9288 - val_age_output_mae: 0.0707 - val_gender_output_accuracy: 0.8962 - val_loss: 1.3927 - val_race_output_accuracy: 0.7776
# Epoch 81/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 618s 2s/step - age_output_mae: 0.0594 - gender_output_accuracy: 0.9739 - loss: 0.3224 - race_output_accuracy: 0.9329 - val_age_output_mae: 0.0689 - val_gender_output_accuracy: 0.8980 - val_loss: 1.3133 - val_race_output_accuracy: 0.7891
# Epoch 82/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 615s 2s/step - age_output_mae: 0.0589 - gender_output_accuracy: 0.9778 - loss: 0.3062 - race_output_accuracy: 0.9344 - val_age_output_mae: 0.0759 - val_gender_output_accuracy: 0.8962 - val_loss: 1.3315 - val_race_output_accuracy: 0.7861
# Epoch 83/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 613s 2s/step - age_output_mae: 0.0581 - gender_output_accuracy: 0.9793 - loss: 0.3088 - race_output_accuracy: 0.9342 - val_age_output_mae: 0.0642 - val_gender_output_accuracy: 0.8954 - val_loss: 1.2947 - val_race_output_accuracy: 0.7851
# Epoch 84/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 612s 2s/step - age_output_mae: 0.0592 - gender_output_accuracy: 0.9788 - loss: 0.3170 - race_output_accuracy: 0.9323 - val_age_output_mae: 0.0699 - val_gender_output_accuracy: 0.8929 - val_loss: 1.3129 - val_race_output_accuracy: 0.7889
# Epoch 85/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 620s 2s/step - age_output_mae: 0.0589 - gender_output_accuracy: 0.9739 - loss: 0.3038 - race_output_accuracy: 0.9347 - val_age_output_mae: 0.0693 - val_gender_output_accuracy: 0.9020 - val_loss: 1.3582 - val_race_output_accuracy: 0.7849
# Epoch 86/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 611s 2s/step - age_output_mae: 0.0583 - gender_output_accuracy: 0.9776 - loss: 0.2947 - race_output_accuracy: 0.9364 - val_age_output_mae: 0.0637 - val_gender_output_accuracy: 0.8913 - val_loss: 1.4589 - val_race_output_accuracy: 0.7746
# Epoch 87/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 617s 2s/step - age_output_mae: 0.0576 - gender_output_accuracy: 0.9745 - loss: 0.2971 - race_output_accuracy: 0.9372 - val_age_output_mae: 0.0660 - val_gender_output_accuracy: 0.8960 - val_loss: 1.3961 - val_race_output_accuracy: 0.7855
# Epoch 88/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 618s 2s/step - age_output_mae: 0.0582 - gender_output_accuracy: 0.9814 - loss: 0.2971 - race_output_accuracy: 0.9357 - val_age_output_mae: 0.0647 - val_gender_output_accuracy: 0.8962 - val_loss: 1.3410 - val_race_output_accuracy: 0.7855
# Epoch 89/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 614s 2s/step - age_output_mae: 0.0577 - gender_output_accuracy: 0.9795 - loss: 0.2954 - race_output_accuracy: 0.9368 - val_age_output_mae: 0.0617 - val_gender_output_accuracy: 0.8958 - val_loss: 1.3511 - val_race_output_accuracy: 0.7875
# Epoch 90/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 602s 2s/step - age_output_mae: 0.0572 - gender_output_accuracy: 0.9830 - loss: 0.2919 - race_output_accuracy: 0.9359 - val_age_output_mae: 0.0616 - val_gender_output_accuracy: 0.8861 - val_loss: 1.3998 - val_race_output_accuracy: 0.7837
# Epoch 91/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 603s 2s/step - age_output_mae: 0.0574 - gender_output_accuracy: 0.9825 - loss: 0.2879 - race_output_accuracy: 0.9381 - val_age_output_mae: 0.0618 - val_gender_output_accuracy: 0.8964 - val_loss: 1.3130 - val_race_output_accuracy: 0.7893
# Epoch 92/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 607s 2s/step - age_output_mae: 0.0568 - gender_output_accuracy: 0.9799 - loss: 0.2728 - race_output_accuracy: 0.9431 - val_age_output_mae: 0.0613 - val_gender_output_accuracy: 0.8958 - val_loss: 1.3365 - val_race_output_accuracy: 0.7891
# Epoch 93/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 610s 2s/step - age_output_mae: 0.0564 - gender_output_accuracy: 0.9803 - loss: 0.2707 - race_output_accuracy: 0.9428 - val_age_output_mae: 0.0651 - val_gender_output_accuracy: 0.8982 - val_loss: 1.2920 - val_race_output_accuracy: 0.7875
# Epoch 94/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 620s 2s/step - age_output_mae: 0.0574 - gender_output_accuracy: 0.9798 - loss: 0.2885 - race_output_accuracy: 0.9370 - val_age_output_mae: 0.0611 - val_gender_output_accuracy: 0.8976 - val_loss: 1.4029 - val_race_output_accuracy: 0.7847
# Epoch 95/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 614s 2s/step - age_output_mae: 0.0566 - gender_output_accuracy: 0.9827 - loss: 0.2540 - race_output_accuracy: 0.9431 - val_age_output_mae: 0.0643 - val_gender_output_accuracy: 0.8938 - val_loss: 1.3712 - val_race_output_accuracy: 0.7869
# Epoch 96/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 602s 2s/step - age_output_mae: 0.0571 - gender_output_accuracy: 0.9817 - loss: 0.2459 - race_output_accuracy: 0.9491 - val_age_output_mae: 0.0607 - val_gender_output_accuracy: 0.8988 - val_loss: 1.2753 - val_race_output_accuracy: 0.7911
# Epoch 97/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 619s 2s/step - age_output_mae: 0.0563 - gender_output_accuracy: 0.9842 - loss: 0.2491 - race_output_accuracy: 0.9448 - val_age_output_mae: 0.0624 - val_gender_output_accuracy: 0.8986 - val_loss: 1.3801 - val_race_output_accuracy: 0.7869
# Epoch 98/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 593s 2s/step - age_output_mae: 0.0568 - gender_output_accuracy: 0.9834 - loss: 0.2625 - race_output_accuracy: 0.9450 - val_age_output_mae: 0.0641 - val_gender_output_accuracy: 0.8889 - val_loss: 1.3929 - val_race_output_accuracy: 0.7869
# Epoch 99/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 407s 1s/step - age_output_mae: 0.0559 - gender_output_accuracy: 0.9820 - loss: 0.2561 - race_output_accuracy: 0.9453 - val_age_output_mae: 0.0699 - val_gender_output_accuracy: 0.8982 - val_loss: 1.2908 - val_race_output_accuracy: 0.7956
# Epoch 100/100
# 362/362 ━━━━━━━━━━━━━━━━━━━━ 242s 667ms/step - age_output_mae: 0.0565 - gender_output_accuracy: 0.9864 - loss: 0.2441 - race_output_accuracy: 0.9469 - val_age_output_mae: 0.0612 - val_gender_output_accuracy: 0.8915 - val_loss: 1.3784 - val_race_output_accuracy: 0.7835

# %%
model.save('./final-model.keras')

# %%
plt.clf()
fig = go.Figure()
fig.add_trace(go.Scatter(
                    y=history.history['race_output_accuracy'],
                    name='Train'))

fig.add_trace(go.Scatter(
                    y=history.history['val_race_output_accuracy'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Accuracy for race feature',
                  xaxis_title='Epoch',
                  yaxis_title='Accuracy')

fig.write_html('acc_race.html', include_plotlyjs='cdn')

fig.show()

# %%
plt.clf()

fig = go.Figure()
fig.add_trace(go.Scatter(
                    y=history.history['gender_output_accuracy'],
                    name='Train'))

fig.add_trace(go.Scatter(
                    y=history.history['val_gender_output_accuracy'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Accuracy for gender feature',
                  xaxis_title='Epoch',
                  yaxis_title='Accuracy')

fig.write_html('acc_gender.html', include_plotlyjs='cdn')

fig.show()

# %%
plt.clf()

fig = go.Figure()
fig.add_trace(go.Scattergl(
                    y=history.history['age_output_mae'],
                    name='Train'))

fig.add_trace(go.Scattergl(
                    y=history.history['val_age_output_mae'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Mean Absolute Error for age feature',
                  xaxis_title='Epoch',
                  yaxis_title='Mean Absolute Error')

fig.write_html('mae_age.html', include_plotlyjs='cdn')

fig.show()

# %%
fig = go.Figure()
fig.add_trace(go.Scattergl(
                    y=history.history['loss'],
                    name='Train'))

fig.add_trace(go.Scattergl(
                    y=history.history['val_loss'],
                    name='Valid'))


fig.update_layout(height=450, 
                  width=600,
                  title='Overall loss',
                  xaxis_title='Epoch',
                  yaxis_title='Loss')

fig.write_html('overall_loss.html', include_plotlyjs='cdn')

fig.show()

# %%
test_batch_size = 128
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
age_pred, race_pred, gender_pred = model.predict(test_generator, 
                                                           steps=len(test_idx)//test_batch_size)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 27s 476ms/step

# %%
test_generator = data_generator.generate_images(test_idx, is_training=False, batch_size=test_batch_size)
samples = 0
images, age_true, race_true, gender_true = [], [], [], []
for test_batch in test_generator:
    image = test_batch[0]
    labels = test_batch[1]
    
    images.extend(image)
    age_true.extend(labels[0])
    race_true.extend(labels[1])
    gender_true.extend(labels[2])
    
age_true = np.array(age_true)
race_true = np.array(race_true)
gender_true = np.array(gender_true)

race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)

age_true = age_true * data_generator.max_age
age_pred = age_pred * data_generator.max_age

# %%
# !pip3 install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp39-cp39-macosx_12_0_arm64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 4.7 MB/s eta 0:00:01
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.0-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 2.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/kailyliu/Library/Python/3.9/lib/python/site-packages (from scikit-learn) (1.26.4)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.0-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 5.1 MB/s eta 0:00:01
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.0 scikit-learn-1.4.2 scipy-1.13.0 threadpoolctl-3.4.0
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from sklearn.metrics import classification_report

cr_race = classification_report(race_true, race_pred, target_names=dataset_dict['race_alias'].keys())
print(cr_race)
# Out:
#               precision    recall  f1-score   support
#
#        white       0.79      0.91      0.84      3014
#        black       0.89      0.80      0.84      1382
#        asian       0.84      0.82      0.83       991
#       indian       0.71      0.72      0.71      1159
#       others       0.51      0.19      0.28       494
#
#     accuracy                           0.79      7040
#    macro avg       0.75      0.69      0.70      7040
# weighted avg       0.78      0.79      0.78      7040

# %%
cr_gender = classification_report(gender_true, gender_pred, target_names=dataset_dict['gender_alias'].keys())
print(cr_gender)
# Out:
#               precision    recall  f1-score   support
#
#         male       0.94      0.86      0.90      3692
#       female       0.86      0.94      0.90      3348
#
#     accuracy                           0.90      7040
#    macro avg       0.90      0.90      0.90      7040
# weighted avg       0.90      0.90      0.90      7040

# %%
from sklearn.metrics import r2_score

print('R2 score for age: ', r2_score(age_true, age_pred))
# Out:
# R2 score for age:  0.7554427536477967

# %%
import math
n = 16
random_indices = np.random.permutation(n)
n_cols = 4
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 17))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(images[img_idx])
    
    cur_age_pred = age_pred[img_idx]
    cur_age_true = age_true[img_idx]
    
    cur_gender_pred = gender_pred[img_idx]
    cur_gender_true = gender_true[img_idx]
    
    cur_race_pred = race_pred[img_idx]
    cur_race_true = race_true[img_idx]
    
    age_threshold = 10
    if cur_gender_pred == cur_gender_true and cur_race_pred == cur_race_true and abs(cur_age_pred - cur_age_true) <= age_threshold:
        ax.xaxis.label.set_color('green')
    elif cur_gender_pred != cur_gender_true and cur_race_pred != cur_race_true and abs(cur_age_pred - cur_age_true) > age_threshold:
        ax.xaxis.label.set_color('red')
    
    ax.set_xlabel('a: {}, g: {}, r: {}'.format(int(age_pred[img_idx]),
                            dataset_dict['gender_id'][gender_pred[img_idx]],
                               dataset_dict['race_id'][race_pred[img_idx]]))
    
    ax.set_title('a: {}, g: {}, r: {}'.format(int(age_true[img_idx]),
                            dataset_dict['gender_id'][gender_true[img_idx]],
                               dataset_dict['race_id'][race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
    
plt.tight_layout()
plt.savefig('preds.png')
# Out:
# /var/folders/1_/blm5ws2x1xldyp8hd9kjclqw0000gn/T/ipykernel_67154/2625015441.py:26: DeprecationWarning:
#
# Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
